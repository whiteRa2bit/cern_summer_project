# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_validate
import tqdm

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import HuberRegressor
from sklearn import linear_model
from sklearn import tree
from sklearn import svm
from sklearn.linear_model import PassiveAggressiveRegressor
import xgboost as xgb
from catboost import CatBoostRegressor

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
from mlxtend.regressor import StackingRegressor
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading data

# %%
def get_data():
    file = open('./data/shashlik_61_pulses.txt', 'r')
    data = file.readlines()
    data = np.array([list(map(float, experiment.split())) for experiment in data])
   
    X = data[:, 2:]
    y_baseline = data[:, 1]
    y = data[:, 0]
    
    return X, y

# %%
def get_freq_data(X, freq=20, start_point=355):
    X_freq = np.concatenate([X[:, start_point::-freq], X[:, start_point::freq]], axis=1)
    return X_freq

# %%
X, y = get_data()

# %% [markdown]
# ### Pipelines

# %%
huber_reg = HuberRegressor(epsilon= 5.09, alpha= 0.0004)
ridge_reg = linear_model.Ridge(solver='saga', max_iter=4000, alpha= 0.582)
lasso_reg = linear_model.Lasso(max_iter=4000, alpha=0.0038, normalize=False)
dt_reg = tree.DecisionTreeRegressor(min_samples_split=7, min_samples_leaf=7, min_weight_fraction_leaf=0.000516, 
                                                                                             max_features='auto')
    
pa_reg = PassiveAggressiveRegressor(max_iter=3600, tol=1e-3)
xgb_reg = xgb.XGBRegressor(objective="reg:linear", alpha= 0.00244, booster='dart', eta= 0.017326, gamma=0.19504, 
                           reg_lambda=0.22451, max_depth=8, verbosity=0)

# %%
models = [huber_reg, ridge_reg, lasso_reg, dt_reg,  xgb_reg] #pa_reg,

# %% [markdown]
# ### Let's find out how scores depend on frequency of sampling

# %%
models_scores = {type(model).__name__:{'r2': [], 'mse': [], 'mae': [], 'rmse': []} for model in models}

# %%
models_scores
# Out:
# {'HuberRegressor': {'r2': [], 'mse': [], 'mae': [], 'rmse': []},
#  'Ridge': {'r2': [], 'mse': [], 'mae': [], 'rmse': []},
#  'Lasso': {'r2': [], 'mse': [], 'mae': [], 'rmse': []},
#  'DecisionTreeRegressor': {'r2': [], 'mse': [], 'mae': [], 'rmse': []},
#  'XGBRegressor': {'r2': [], 'mse': [], 'mae': [], 'rmse': []}}

# %%
freq_range = range(20, 70, 10)

for freq in freq_range:
    print("Frequency:", freq)
    X, y = get_data()
    X = get_freq_data(X, freq=freq)
    for model in models:    
        model_name = type(model).__name__
        print("Metaregressor:", model_name)
        stregr = StackingRegressor(regressors=models, meta_regressor=model)
        scoring = ['r2', 'neg_mean_squared_error', 'neg_mean_absolute_error']
        scores = cross_validate(stregr, X, y, scoring=scoring, cv=5)
 
        r2_score_mean = scores['test_r2'].mean()
        r2_score_std = scores['test_r2'].std()
        mse_score_mean = -scores['test_neg_mean_squared_error'].mean()
        mse_score_std = scores['test_neg_mean_squared_error'].std()
        mae_score_mean = -scores['test_neg_mean_absolute_error'].mean()
        mae_score_std = scores['test_neg_mean_absolute_error'].std()
        rmse_score_mean = np.sqrt(-scores['test_neg_mean_squared_error']).mean()
        rmse_score_std = np.sqrt(-scores['test_neg_mean_squared_error']).std()
        
        cur_scores = [(r2_score_mean, r2_score_std), (mse_score_mean, mse_score_std),\
                          (mae_score_mean, mae_score_std), (rmse_score_mean, rmse_score_std)]
#         print('!!!!!!!!')
#         print("TEST")
#         print(models_scores[type(models[0]).__name__]['r2'])
#         print('!!!!!!!!')
        print("95% confindence interval:")
        for i, metric in enumerate(['r2', 'mse', 'mae', 'rmse'], 0):
            models_scores[model_name][metric].append(cur_scores[i])
            print(metric, "score: %0.5f (+/- %0.5f)" % (cur_scores[i][0], 2*cur_scores[i][1]))
        print('----------------------------------')
    print('____________________________________________________________')
    print()
# Out:
# Frequency: 20
# Metaregressor: HuberRegressor
# 95% confindence interval:
# r2 score: 0.99945 (+/- 0.00006)
# mse score: 0.09017 (+/- 0.00903)
# mae score: 0.23300 (+/- 0.00851)
# rmse score: 0.30019 (+/- 0.01515)
# ----------------------------------
# Metaregressor: Ridge
# 95% confindence interval:
# r2 score: 0.99944 (+/- 0.00006)
# mse score: 0.09100 (+/- 0.00921)
# mae score: 0.23391 (+/- 0.00882)
# rmse score: 0.30156 (+/- 0.01539)
# ----------------------------------
# Metaregressor: Lasso
# 95% confindence interval:
# r2 score: 0.99932 (+/- 0.00009)
# mse score: 0.11010 (+/- 0.01213)
# mae score: 0.25671 (+/- 0.01133)
# rmse score: 0.33169 (+/- 0.01828)
# ----------------------------------
# Metaregressor: DecisionTreeRegressor
# 95% confindence interval:
# r2 score: 0.99939 (+/- 0.00006)
# mse score: 0.09880 (+/- 0.00892)
# mae score: 0.24598 (+/- 0.00723)
# rmse score: 0.31424 (+/- 0.01424)
# ----------------------------------
# Metaregressor: XGBRegressor
# 95% confindence interval:
# r2 score: 0.99941 (+/- 0.00005)
# mse score: 0.09574 (+/- 0.00832)
# mae score: 0.24209 (+/- 0.00754)
# rmse score: 0.30935 (+/- 0.01354)
# ----------------------------------
# ____________________________________________________________
#
# Frequency: 30
# Metaregressor: HuberRegressor
# 95% confindence interval:
# r2 score: 0.99936 (+/- 0.00004)
# mse score: 0.10340 (+/- 0.00243)
# mae score: 0.24920 (+/- 0.00404)
# rmse score: 0.32155 (+/- 0.00379)
# ----------------------------------
# Metaregressor: Ridge
# 95% confindence interval:
# r2 score: 0.99936 (+/- 0.00003)
# mse score: 0.10402 (+/- 0.00259)
# mae score: 0.25004 (+/- 0.00408)
# rmse score: 0.32252 (+/- 0.00402)
# ----------------------------------
# Metaregressor: Lasso
# 95% confindence interval:
# r2 score: 0.99925 (+/- 0.00006)
# mse score: 0.12223 (+/- 0.00692)
# mae score: 0.27008 (+/- 0.00796)
# rmse score: 0.34958 (+/- 0.00990)
# ----------------------------------
# Metaregressor: DecisionTreeRegressor
# 95% confindence interval:
# r2 score: 0.99930 (+/- 0.00004)
# mse score: 0.11362 (+/- 0.00139)
# mae score: 0.26355 (+/- 0.00181)
# rmse score: 0.33707 (+/- 0.00207)
# ----------------------------------
# Metaregressor: XGBRegressor
# 95% confindence interval:
# r2 score: 0.99932 (+/- 0.00003)
# mse score: 0.11114 (+/- 0.00304)
# mae score: 0.26092 (+/- 0.00372)
# rmse score: 0.33337 (+/- 0.00456)
# ----------------------------------
# ____________________________________________________________
#
# Frequency: 40
# Metaregressor: HuberRegressor
# 95% confindence interval:
# r2 score: 0.99921 (+/- 0.00006)
# mse score: 0.12872 (+/- 0.01230)
# mae score: 0.27603 (+/- 0.01194)
# rmse score: 0.35867 (+/- 0.01713)
# ----------------------------------
# Metaregressor: Ridge
# 95% confindence interval:
# r2 score: 0.99920 (+/- 0.00006)
# mse score: 0.12977 (+/- 0.01246)
# mae score: 0.27702 (+/- 0.01184)
# rmse score: 0.36013 (+/- 0.01729)
# ----------------------------------
# Metaregressor: Lasso
# 95% confindence interval:
# r2 score: 0.99914 (+/- 0.00007)
# mse score: 0.13992 (+/- 0.01387)
# mae score: 0.28712 (+/- 0.01204)
# rmse score: 0.37394 (+/- 0.01855)
# ----------------------------------
# Metaregressor: DecisionTreeRegressor
# 95% confindence interval:
# r2 score: 0.99911 (+/- 0.00009)
# mse score: 0.14401 (+/- 0.01514)
# mae score: 0.29567 (+/- 0.01267)
# rmse score: 0.37936 (+/- 0.01988)
# ----------------------------------
# Metaregressor: XGBRegressor
# 95% confindence interval:
# r2 score: 0.99915 (+/- 0.00006)
# mse score: 0.13776 (+/- 0.01058)
# mae score: 0.28755 (+/- 0.01012)
# rmse score: 0.37109 (+/- 0.01422)
# ----------------------------------
# ____________________________________________________________
#
# Frequency: 50
# Metaregressor: HuberRegressor
# 95% confindence interval:
# r2 score: 0.99908 (+/- 0.00005)
# mse score: 0.15021 (+/- 0.00334)
# mae score: 0.29843 (+/- 0.00520)
# rmse score: 0.38757 (+/- 0.00431)
# ----------------------------------
# Metaregressor: Ridge
# 95% confindence interval:
# r2 score: 0.99907 (+/- 0.00005)
# mse score: 0.15078 (+/- 0.00356)
# mae score: 0.29880 (+/- 0.00529)
# rmse score: 0.38830 (+/- 0.00459)
# ----------------------------------
# Metaregressor: Lasso
# 95% confindence interval:
# r2 score: 0.99904 (+/- 0.00004)
# mse score: 0.15652 (+/- 0.00512)
# mae score: 0.30301 (+/- 0.00597)
# rmse score: 0.39562 (+/- 0.00651)
# ----------------------------------
# Metaregressor: DecisionTreeRegressor
# 95% confindence interval:
# r2 score: 0.99897 (+/- 0.00010)
# mse score: 0.16694 (+/- 0.01193)
# mae score: 0.31711 (+/- 0.01227)
# rmse score: 0.40852 (+/- 0.01453)
# ----------------------------------
# Metaregressor: XGBRegressor
# 95% confindence interval:
# r2 score: 0.99902 (+/- 0.00007)
# mse score: 0.15955 (+/- 0.00544)
# mae score: 0.31006 (+/- 0.00551)
# rmse score: 0.39942 (+/- 0.00678)
# ----------------------------------
# ____________________________________________________________
#
# Frequency: 60
# Metaregressor: HuberRegressor
# 95% confindence interval:
# r2 score: 0.99899 (+/- 0.00006)
# mse score: 0.16358 (+/- 0.00953)
# mae score: 0.30528 (+/- 0.00420)
# rmse score: 0.40441 (+/- 0.01174)
# ----------------------------------
# Metaregressor: Ridge
# 95% confindence interval:
# r2 score: 0.99899 (+/- 0.00006)
# mse score: 0.16426 (+/- 0.00985)
# mae score: 0.30569 (+/- 0.00450)
# rmse score: 0.40525 (+/- 0.01211)
# ----------------------------------
# Metaregressor: Lasso
# 95% confindence interval:
# r2 score: 0.99895 (+/- 0.00008)
# mse score: 0.17059 (+/- 0.01147)
# mae score: 0.31040 (+/- 0.00517)
# rmse score: 0.41296 (+/- 0.01386)
# ----------------------------------
# Metaregressor: DecisionTreeRegressor
# 95% confindence interval:
# r2 score: 0.99889 (+/- 0.00011)
# mse score: 0.18032 (+/- 0.01020)
# mae score: 0.32331 (+/- 0.01068)
# rmse score: 0.42460 (+/- 0.01208)
# ----------------------------------
# Metaregressor: XGBRegressor
# 95% confindence interval:
# r2 score: 0.99893 (+/- 0.00008)
# mse score: 0.17374 (+/- 0.00993)
# mae score: 0.31703 (+/- 0.00796)
# rmse score: 0.41677 (+/- 0.01193)
# ----------------------------------
# ____________________________________________________________

# %% [markdown]
# ### Save our results

# %%
import pickle

def save_obj(obj, name ):
    with open('./data/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        
def load_obj(name ):
    with open('./data/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
# save_obj(models_scores, 'models_scores')

# %%
models_scores = load_obj('models_scores')

# %% [markdown]
# ### Lets plot our results

# %%
colors = ['b', 'g', 'r', 'c', 'y', 'k']

for metric in ['r2', 'mse', 'mae', 'rmse']:
    for i in range(len(models)):
        plt.title(metric)
        plt.xlabel('Frequency')
        plt.plot(np.array(models_scores[type(models[i]).__name__][metric])[:, 0], color=colors[i])
        plt.xticks([i for i in range(0, len(models) - 1)], [20, 30, 40, 50, 60])
        plt.legend([type(model).__name__ for model in models])
    plt.show()

# %% [markdown]
# ### Confidence interval

# %%
import matplotlib.patches as mpatches
from matplotlib.colors import colorConverter as cc

from pylab import rcParams
rcParams['figure.figsize'] = 7, 15

def plot_mean_and_CI(mean, lb, ub, color_mean=None, color_shading=None, xticks=freq_range):
    lb = mean + lb
    ub = mean + ub
    # plot the shaded range of the confidence intervals
    plt.fill_between(range(mean.shape[0]), ub, lb,
                     color=color_shading, alpha=.5)
    # plot the mean on top
#     plt.xticks(xticks)
    plt.plot(mean, color_mean)

# %%
def plot_confidence_interval(metric):
    for i in range(len(models)):
        plt.subplot(511 + i)
        plt.title(type(models[i]).__name__)
        plt.xticks([i for i in range(0, len(models))], [20, 30, 40, 50, 60])
        plot_mean_and_CI(np.array(models_scores[type(models[i]).__name__][metric])[:, 0],\
                            -np.array(models_scores[type(models[i]).__name__][metric])[:, 1],\
                             np.array(models_scores[type(models[i]).__name__][metric])[:, 1],\
                                 color_mean=colors[i], color_shading=colors[i])

# %% [markdown]
# ##### R2

# %%
plot_confidence_interval('r2')

# %% [markdown]
# ##### MSE

# %%
plot_confidence_interval('mse')

# %% [markdown]
# ##### MAE

# %%
plot_confidence_interval('mae')

# %% [markdown]
# ##### RMSE

# %%
plot_confidence_interval('rmse')
