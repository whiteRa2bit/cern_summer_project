# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import tqdm
from datetime import datetime

# %%
file = open('./data/shashlik_61_pulses.txt', 'r')
data = file.readlines()
data = np.array([list(map(float, experiment.split())) for experiment in data])

# %%
data.shape
# Out:
# (7848, 1026)

# %%
print("Experiments number:", data.shape[0])
# Out:
# Experiments number: 7848

# %%
y = data[:, 0]
y_baseline = data[:, 1]
X = data[:, 2:]

# %%
plt.hist(y)
# Out:
# (array([ 102.,  515.,  998., 1123., 1050., 1073., 1044., 1037.,  714.,
#          192.]),
#  array([137.035 , 142.8179, 148.6008, 154.3837, 160.1666, 165.9495,
#         171.7324, 177.5153, 183.2982, 189.0811, 194.864 ]),
#  <a list of 10 Patch objects>)

# %%
test_dt = datetime.strptime('09.12.2018', '%d.%m.%Y')

# %%
test_dt
# Out:
# datetime.datetime(2018, 12, 9, 0, 0)

# %% [markdown]
# ### Normalize y

# %%
y = y - np.mean(y)

# %%
y_baseline = y_baseline - np.mean(y_baseline)

# %% [markdown]
# ### Model

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.metrics import recall_score
from sklearn.preprocessing import PolynomialFeatures

# %%
def print_lr_scores(X, reg=LinearRegression()):
    scoring = ['r2', 'neg_mean_squared_error', 'neg_mean_absolute_error']
    scores = cross_validate(reg, X, y, scoring=scoring, cv=5)
    
    print("95% confidence interval:")
    print("r2_score: %0.5f (+/- %0.5f)" % (scores['test_r2'].mean(), scores['test_r2'].std() * 2))
    print("MSE: %0.5f (+/- %0.5f)" % (-scores['test_neg_mean_squared_error'].mean(), scores['test_neg_mean_squared_error'].std() * 2))
    print("MAE: %0.5f (+/- %0.5f)" % (-scores['test_neg_mean_absolute_error'].mean(), scores['test_neg_mean_absolute_error'].std() * 2))

# %% [markdown]
# #### Linear regression metrics

# %%
print_lr_scores(X)
# Out:
# 95% confidence interval:
# r2_score: 0.99904 (+/- 0.00008)
# MSE: 0.15693 (+/- 0.01474)
# MAE: 0.30628 (+/- 0.01495)

# %% [markdown]
# #### Baseline metrics

# %%
print("r2_score:", r2_score(y, y_baseline))
print("MSE:", mean_squared_error(y, y_baseline))
print("MAE:", mean_absolute_error(y, y_baseline))
# Out:
# r2_score: 0.9994485733281531
# MSE: 0.08974125778045815
# MAE: 0.23497220510936273

# %% [markdown]
# ### Let's plot errors distribution

# %% [markdown]
# ##### Train-test split

# %%
X_train, X_test, y_train, y_test, y_baseline_train, y_baseline_test = train_test_split(X, y, y_baseline, test_size=0.33, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
predicted = reg.predict(X_test)

# %%
regression_diff = predicted - y_test

# %%
plt.title("Prediction difference for linear regression")
plt.hist(regression_diff)
plt.show()

# %%
baseline_diff = y_baseline_test - y_test

# %%
plt.title("Prediction difference for baseline")
plt.hist(baseline_diff)
plt.show()

# %%
plt.hist(y)
# Out:
# (array([ 102.,  515.,  998., 1123., 1050., 1073., 1044., 1037.,  714.,
#          192.]), array([-29.70791514, -23.92501514, -18.14211514, -12.35921514,
#          -6.57631514,  -0.79341514,   4.98948486,  10.77238486,
#          16.55528486,  22.33818486,  28.12108486]), <a list of 10 Patch objects>)

# %% [markdown]
# ### Experiments with signal frequency

# %%
def plot_errors(model, frequency_values, start_point=355):
    r2_scores = []
    mse_scores = []
    mae_scores = []

    for freq in tqdm.tqdm(frequency_values):
        X_freq = np.concatenate([X[:, start_point::-freq][:, ::-1], X[:, start_point + freq::freq]], axis=1)

        scoring = ['r2', 'neg_mean_squared_error', 'neg_mean_absolute_error']
        scores = cross_validate(model, X_freq, y, scoring=scoring, cv=5)

        r2_scores.append(scores['test_r2'].mean())
        mse_scores.append(scores['test_neg_mean_squared_error'].mean())
        mae_scores.append(scores['test_neg_mean_absolute_error'].mean())
        
    plt.title("R2 score dependency on number of samples for " + type(model).__name__)
    plt.plot(frequency_values, r2_scores)
    plt.show()
    
    plt.title("MSE and MAE dependencies on number of samples for " + type(model).__name__)
    plt.plot(frequency_values, mse_scores)
    plt.plot(frequency_values, mae_scores)
    plt.legend(('MSE', 'MAE'),
               loc='lower left')
    plt.show()

# %%
plt.rcParams["figure.figsize"] = [10, 8]

reg = LinearRegression()

frequency_values = range(2, 1000)
plot_errors(reg, frequency_values)

frequency_values = range(2, 100)
plot_errors(reg, frequency_values)
# Out:
# 100%|██████████| 998/998 [00:32<00:00, 30.95it/s]
# 100%|██████████| 98/98 [00:20<00:00,  4.75it/s]

# %%
from sklearn.linear_model import HuberRegressor

huber_reg = HuberRegressor(epsilon= 5.09, alpha= 0.0004)


frequency_values = range(2, 1000)
plot_errors(huber_reg, frequency_values)

frequency_values = range(2, 100)
plot_errors(huber_reg, frequency_values)
# Out:
# 100%|██████████| 998/998 [06:43<00:00,  2.47it/s]
# 100%|██████████| 98/98 [02:30<00:00,  1.54s/it]

# %%
X = X[:1000]
y = y[:1000]

# %%
import xgboost as xgb

xgb_reg = xgb.XGBRegressor(objective="reg:linear", random_state=42, verbosity=0)

# frequency_values = range(2, 1000)
# plot_errors(xgb_reg, frequency_values)

frequency_values = range(2, 500)
plot_errors(xgb_reg, frequency_values)

frequency_values = range(2, 100)
plot_errors(xgb_reg, frequency_values)
# Out:
# 100%|██████████| 498/498 [03:43<00:00,  2.23it/s]
# 100%|██████████| 98/98 [01:57<00:00,  1.20s/it]

# %%
frequency_values = range(2, 100)

plot_errors(LinearRegression(), frequency_values)

# %% [markdown]
# #### As we may see, if we take freq = 20, we significantly reduce the size of our data and have the same errors rate

# %% [markdown]
# ### Trying other models

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
freq = 20
start_point = 355

X = np.concatenate([X[:, start_point::-freq], X[:, start_point::freq]], axis=1)

# %%
X.shape
# Out:
# (7848, 52)

# %%
poly = PolynomialFeatures(2)
X_polynomial = poly.fit_transform(X)

# %%
X_polynomial.shape
# Out:
# (7848, 1431)

# %%
print("Linear regresssion metrics:")
print_lr_scores(X)
# Out:
# Linear regresssion metrics:
# 95% confindence interval:
# r2_score: 0.99910 (+/- 0.00006)
# MSE: 0.14703 (+/- 0.01111)
# MAE: 0.29564 (+/- 0.01264)

# %%
print("Polynomial linear regression metrics:")
print_lr_scores(X_polynomial)
# Out:
# Polynomial linear regression metrics:
# 95% confindence interval:
# r2_score: 0.99961 (+/- 0.00002)
# MSE: 0.06373 (+/- 0.00395)
# MAE: 0.19767 (+/- 0.00591)

# %%
print("Baseline metrics:")
print("r2_score:", r2_score(y, y_baseline))
print("MSE:", mean_squared_error(y, y_baseline))
print("MAE:", mean_absolute_error(y, y_baseline))
# Out:
# Baseline metrics:
# r2_score: 0.9994485733281531
# MSE: 0.08974125778045815
# MAE: 0.23497220510936273

# %% [markdown]
# ###### Linear regression provides worse result than the baseline solution, but we can beat the baseline solution with adding polynomial features

# %% [markdown]
# ### Huber Regressor

# %%
from sklearn.linear_model import HuberRegressor

# %%
huber = HuberRegressor()

# %%
print_lr_scores(X, huber)
# Out:
# 95% confindence interval:
# r2_score: 0.99906 (+/- 0.00008)
# MSE: 0.15299 (+/- 0.01295)
# MAE: 0.30164 (+/- 0.01305)

# %%
print_lr_scores(X_polynomial, huber)
# Out:
# 95% confindence interval:
# r2_score: 0.99941 (+/- 0.00007)
# MSE: 0.09641 (+/- 0.01677)
# MAE: 0.24163 (+/- 0.02070)

# %% [markdown]
# ### Ridge linear regression

# %%
from sklearn import linear_model
ridge_reg = linear_model.Ridge(alpha=.5)

# %%
print_lr_scores(X, ridge_reg)
# Out:
# 95% confindence interval:
# r2_score: 0.99910 (+/- 0.00006)
# MSE: 0.14706 (+/- 0.01099)
# MAE: 0.29566 (+/- 0.01244)

# %%
print_lr_scores(X_polynomial, ridge_reg)
# Out:
# 95% confindence interval:
# r2_score: 0.99961 (+/- 0.00002)
# MSE: 0.06302 (+/- 0.00398)
# MAE: 0.19658 (+/- 0.00580)

# %% [markdown]
# ### Lasso linear regression

# %%
lasso_reg = linear_model.Lasso(alpha=0.1)

# %%
print_lr_scores(X, lasso_reg)
# Out:
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 95% confindence interval:
# r2_score: 0.99908 (+/- 0.00007)
# MSE: 0.15038 (+/- 0.01211)
# MAE: 0.29950 (+/- 0.01433)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
print_lr_scores(X_polynomial, lasso_reg)
# Out:
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 95% confindence interval:
# r2_score: 0.99956 (+/- 0.00001)
# MSE: 0.07211 (+/- 0.00367)
# MAE: 0.20930 (+/- 0.00561)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# ### Decision trees

# %%
from sklearn import tree

dt_reg = tree.DecisionTreeRegressor()

# %%
print_lr_scores(X, dt_reg)
# Out:
# 95% confindence interval:
# r2_score: 0.99881 (+/- 0.00018)
# MSE: 0.19336 (+/- 0.02436)
# MAE: 0.34003 (+/- 0.01891)

# %%
print_lr_scores(X_polynomial, dt_reg)
# Out:
# 95% confindence interval:
# r2_score: 0.99888 (+/- 0.00005)
# MSE: 0.18170 (+/- 0.00699)
# MAE: 0.32915 (+/- 0.00732)

# %% [markdown]
# ### SVM

# %%
from sklearn import svm

# %%
svm_reg = svm.SVR()

# %%
print_lr_scores(X, svm_reg)
# Out:
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/pavel/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 95% confindence interval:
# r2_score: -0.00096 (+/- 0.00135)
# MSE: 162.82265 (+/- 9.49223)
# MAE: 10.90944 (+/- 0.37305)

# %%
# print_lr_scores(X_polynomial, svm_reg)

# %% [markdown]
# ### Passive aggresive

# %%
from sklearn.linear_model import PassiveAggressiveRegressor

# %%
pa_reg = PassiveAggressiveRegressor(max_iter=1000, random_state=0, tol=1e-3)

# %%
print_lr_scores(X, pa_reg)
# Out:
# 95% confindence interval:
# r2_score: 0.99894 (+/- 0.00008)
# MSE: 0.17244 (+/- 0.00563)
# MAE: 0.32046 (+/- 0.01652)

# %%
print_lr_scores(X_polynomial, pa_reg)
# Out:
# 95% confindence interval:
# r2_score: 0.99804 (+/- 0.00190)
# MSE: 0.31692 (+/- 0.30276)
# MAE: 0.45522 (+/- 0.27130)

# %% [markdown]
# ### Xgboost

# %%
import xgboost as xgb

# %%
xgb_reg = xgb.XGBRegressor(objective="reg:linear", random_state=42)

# %%
print_lr_scores(X, xgb_reg)
# Out:
# [15:32:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:32:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 95% confindence interval:
# r2_score: 0.99939 (+/- 0.00005)
# MSE: 0.09974 (+/- 0.00859)
# MAE: 0.24625 (+/- 0.00999)

# %%
print_lr_scores(X_polynomial, xgb_reg)
# Out:
# [15:32:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:33:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:34:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 95% confindence interval:
# r2_score: 0.99939 (+/- 0.00006)
# MSE: 0.10001 (+/- 0.01135)
# MAE: 0.24677 (+/- 0.01115)

# %% [markdown]
# ### Catboost

# %%
from catboost import CatBoostRegressor

# %%
catboost_reg = CatBoostRegressor(iterations=100,
                          learning_rate=1,
                          depth=5)

# %%
print_lr_scores(X, catboost_reg)
# Out:
# 0:	learn: 4.6898674	total: 224ms	remaining: 22.2s
# 1:	learn: 3.4921055	total: 300ms	remaining: 14.7s
# 2:	learn: 2.9658912	total: 379ms	remaining: 12.3s
# 3:	learn: 2.6853177	total: 465ms	remaining: 11.2s
# 4:	learn: 2.3589750	total: 580ms	remaining: 11s
# 5:	learn: 2.2441001	total: 657ms	remaining: 10.3s
# 6:	learn: 2.2070159	total: 769ms	remaining: 10.2s
# 7:	learn: 1.9256363	total: 852ms	remaining: 9.79s
# 8:	learn: 1.8429953	total: 930ms	remaining: 9.4s
# 9:	learn: 1.8040305	total: 1.02s	remaining: 9.23s
# 10:	learn: 1.7851247	total: 1.12s	remaining: 9.06s
# 11:	learn: 1.6763622	total: 1.2s	remaining: 8.79s
# 12:	learn: 1.5769994	total: 1.3s	remaining: 8.72s
# 13:	learn: 1.4978396	total: 1.4s	remaining: 8.57s
# 14:	learn: 1.4128737	total: 1.47s	remaining: 8.34s
# 15:	learn: 1.2540242	total: 1.57s	remaining: 8.27s
# 16:	learn: 1.2201544	total: 1.68s	remaining: 8.2s
# 17:	learn: 1.1618543	total: 1.76s	remaining: 8.01s
# 18:	learn: 1.0770021	total: 1.86s	remaining: 7.92s
# 19:	learn: 1.0464847	total: 1.96s	remaining: 7.84s
# 20:	learn: 1.0158638	total: 2.05s	remaining: 7.72s
# 21:	learn: 0.9903369	total: 2.17s	remaining: 7.7s
# 22:	learn: 0.9446745	total: 2.25s	remaining: 7.53s
# 23:	learn: 0.9213608	total: 2.33s	remaining: 7.39s
# 24:	learn: 0.9124143	total: 2.5s	remaining: 7.51s
# 25:	learn: 0.9060677	total: 2.67s	remaining: 7.59s
# 26:	learn: 0.8893101	total: 2.84s	remaining: 7.68s
# 27:	learn: 0.8709764	total: 3s	remaining: 7.7s
# 28:	learn: 0.8661866	total: 3.14s	remaining: 7.69s
# 29:	learn: 0.8598371	total: 3.27s	remaining: 7.62s
# 30:	learn: 0.8503024	total: 3.36s	remaining: 7.48s
# 31:	learn: 0.8344947	total: 3.48s	remaining: 7.39s
# 32:	learn: 0.8286658	total: 3.62s	remaining: 7.36s
# 33:	learn: 0.8255064	total: 3.81s	remaining: 7.4s
# 34:	learn: 0.8015314	total: 3.98s	remaining: 7.4s
# 35:	learn: 0.7943169	total: 4.14s	remaining: 7.37s
# 36:	learn: 0.7888228	total: 4.3s	remaining: 7.32s
# 37:	learn: 0.7835982	total: 4.38s	remaining: 7.15s
# 38:	learn: 0.7770535	total: 4.47s	remaining: 6.99s
# 39:	learn: 0.7729788	total: 4.58s	remaining: 6.87s
# 40:	learn: 0.7693865	total: 4.67s	remaining: 6.72s
# 41:	learn: 0.7656083	total: 4.75s	remaining: 6.56s
# 42:	learn: 0.7471152	total: 4.87s	remaining: 6.45s
# 43:	learn: 0.7447011	total: 4.95s	remaining: 6.3s
# 44:	learn: 0.7391721	total: 5.04s	remaining: 6.16s
# 45:	learn: 0.7350222	total: 5.15s	remaining: 6.04s
# 46:	learn: 0.7305948	total: 5.24s	remaining: 5.91s
# 47:	learn: 0.7264918	total: 5.32s	remaining: 5.76s
# 48:	learn: 0.7226913	total: 5.43s	remaining: 5.65s
# 49:	learn: 0.7198328	total: 5.52s	remaining: 5.52s
# 50:	learn: 0.7093565	total: 5.61s	remaining: 5.39s
# 51:	learn: 0.7064023	total: 5.73s	remaining: 5.29s
# 52:	learn: 0.6906193	total: 5.82s	remaining: 5.16s
# 53:	learn: 0.6891646	total: 5.9s	remaining: 5.02s
# 54:	learn: 0.6860843	total: 6.01s	remaining: 4.92s
# 55:	learn: 0.6823864	total: 6.11s	remaining: 4.8s
# 56:	learn: 0.6738873	total: 6.19s	remaining: 4.67s
# 57:	learn: 0.6653573	total: 6.3s	remaining: 4.56s
# 58:	learn: 0.6607409	total: 6.39s	remaining: 4.44s
# 59:	learn: 0.6576922	total: 6.47s	remaining: 4.32s
# 60:	learn: 0.6548372	total: 6.59s	remaining: 4.21s
# 61:	learn: 0.6516548	total: 6.77s	remaining: 4.15s
# 62:	learn: 0.6482284	total: 6.98s	remaining: 4.1s
# 63:	learn: 0.6446854	total: 7.14s	remaining: 4.02s
# 64:	learn: 0.6406374	total: 7.3s	remaining: 3.93s
# 65:	learn: 0.6385020	total: 7.45s	remaining: 3.84s
# 66:	learn: 0.6363417	total: 7.66s	remaining: 3.77s
# 67:	learn: 0.6334588	total: 7.85s	remaining: 3.69s
# 68:	learn: 0.6301313	total: 8.04s	remaining: 3.61s
# 69:	learn: 0.6277705	total: 8.23s	remaining: 3.53s
# 70:	learn: 0.6251720	total: 8.42s	remaining: 3.44s
# 71:	learn: 0.6213721	total: 8.58s	remaining: 3.34s
# 72:	learn: 0.6185912	total: 8.75s	remaining: 3.24s
# 73:	learn: 0.6142222	total: 8.92s	remaining: 3.13s
# 74:	learn: 0.6096692	total: 9.04s	remaining: 3.01s
# 75:	learn: 0.6067736	total: 9.14s	remaining: 2.89s
# 76:	learn: 0.6041635	total: 9.23s	remaining: 2.76s
# 77:	learn: 0.6015443	total: 9.35s	remaining: 2.64s
# 78:	learn: 0.5993747	total: 9.45s	remaining: 2.51s
# 79:	learn: 0.5945210	total: 9.53s	remaining: 2.38s
# 80:	learn: 0.5912760	total: 9.66s	remaining: 2.27s
# 81:	learn: 0.5886643	total: 9.86s	remaining: 2.16s
# 82:	learn: 0.5859109	total: 10s	remaining: 2.06s
# 83:	learn: 0.5837229	total: 10.2s	remaining: 1.94s
# 84:	learn: 0.5799700	total: 10.4s	remaining: 1.83s
# 85:	learn: 0.5690977	total: 10.5s	remaining: 1.7s
# 86:	learn: 0.5534959	total: 10.6s	remaining: 1.58s
# 87:	learn: 0.5502457	total: 10.7s	remaining: 1.46s
# 88:	learn: 0.5459798	total: 10.8s	remaining: 1.33s
# 89:	learn: 0.5434936	total: 11s	remaining: 1.22s
# 90:	learn: 0.5395939	total: 11.2s	remaining: 1.11s
# 91:	learn: 0.5356260	total: 11.4s	remaining: 991ms
# 92:	learn: 0.5336012	total: 11.5s	remaining: 868ms
# 93:	learn: 0.5308405	total: 11.6s	remaining: 742ms
# 94:	learn: 0.5286351	total: 11.7s	remaining: 616ms
# 95:	learn: 0.5174136	total: 11.8s	remaining: 494ms
# 96:	learn: 0.5144535	total: 11.9s	remaining: 370ms
# 97:	learn: 0.5121730	total: 12s	remaining: 246ms
# 98:	learn: 0.5059059	total: 12.2s	remaining: 123ms
# 99:	learn: 0.5034862	total: 12.3s	remaining: 0us
# 0:	learn: 4.9765177	total: 107ms	remaining: 10.6s
# 1:	learn: 3.8425522	total: 262ms	remaining: 12.8s
# 2:	learn: 3.2002661	total: 455ms	remaining: 14.7s
# 3:	learn: 3.1047544	total: 628ms	remaining: 15.1s
# 4:	learn: 2.7801137	total: 762ms	remaining: 14.5s
# 5:	learn: 2.6293934	total: 920ms	remaining: 14.4s
# 6:	learn: 2.3901215	total: 1.13s	remaining: 15s
# 7:	learn: 2.2095424	total: 1.3s	remaining: 14.9s
# 8:	learn: 2.1253750	total: 1.45s	remaining: 14.6s
# 9:	learn: 2.1064244	total: 1.53s	remaining: 13.8s
# 10:	learn: 2.0348471	total: 1.62s	remaining: 13.1s
# 11:	learn: 1.7230256	total: 1.73s	remaining: 12.7s
# 12:	learn: 1.6579596	total: 1.82s	remaining: 12.2s
# 13:	learn: 1.5335552	total: 1.91s	remaining: 11.7s
# 14:	learn: 1.4562518	total: 2.04s	remaining: 11.5s
# 15:	learn: 1.4230450	total: 2.23s	remaining: 11.7s
# 16:	learn: 1.3756900	total: 2.39s	remaining: 11.7s
# 17:	learn: 1.3543301	total: 2.54s	remaining: 11.6s
# 18:	learn: 1.2920362	total: 2.69s	remaining: 11.5s
# 19:	learn: 1.2600553	total: 2.78s	remaining: 11.1s
# 20:	learn: 1.1933817	total: 2.87s	remaining: 10.8s
# 21:	learn: 1.0960222	total: 2.98s	remaining: 10.6s
# 22:	learn: 1.0845087	total: 3.07s	remaining: 10.3s
# 23:	learn: 1.0647563	total: 3.17s	remaining: 10s
# 24:	learn: 1.0458871	total: 3.29s	remaining: 9.86s
# 25:	learn: 1.0364910	total: 3.38s	remaining: 9.62s
# 26:	learn: 0.9365428	total: 3.48s	remaining: 9.41s
# 27:	learn: 0.8935542	total: 3.58s	remaining: 9.21s
# 28:	learn: 0.8727043	total: 3.68s	remaining: 9.01s
# 29:	learn: 0.8655694	total: 3.88s	remaining: 9.06s
# 30:	learn: 0.8601201	total: 4.05s	remaining: 9.02s
# 31:	learn: 0.8403838	total: 4.22s	remaining: 8.97s
# 32:	learn: 0.8328960	total: 4.31s	remaining: 8.76s
# 33:	learn: 0.8204012	total: 4.43s	remaining: 8.6s
# 34:	learn: 0.8160987	total: 4.61s	remaining: 8.55s
# 35:	learn: 0.7948609	total: 4.78s	remaining: 8.49s
# 36:	learn: 0.7844969	total: 4.94s	remaining: 8.41s
# 37:	learn: 0.7775407	total: 5.1s	remaining: 8.33s
# 38:	learn: 0.7741557	total: 5.26s	remaining: 8.23s
# 39:	learn: 0.7708423	total: 5.5s	remaining: 8.25s
# 40:	learn: 0.7673637	total: 5.69s	remaining: 8.19s
# 41:	learn: 0.7614304	total: 5.88s	remaining: 8.12s
# 42:	learn: 0.7560486	total: 6.06s	remaining: 8.03s
# 43:	learn: 0.7519926	total: 6.24s	remaining: 7.94s
# 44:	learn: 0.7249551	total: 6.37s	remaining: 7.79s
# 45:	learn: 0.7211397	total: 6.47s	remaining: 7.59s
# 46:	learn: 0.7054936	total: 6.57s	remaining: 7.41s
# 47:	learn: 0.7023813	total: 6.69s	remaining: 7.25s
# 48:	learn: 0.6949671	total: 6.81s	remaining: 7.09s
# 49:	learn: 0.6789371	total: 6.91s	remaining: 6.91s
# 50:	learn: 0.6672506	total: 7.04s	remaining: 6.76s
# 51:	learn: 0.6627413	total: 7.15s	remaining: 6.6s
# 52:	learn: 0.6572065	total: 7.26s	remaining: 6.44s
# 53:	learn: 0.6552491	total: 7.35s	remaining: 6.26s
# 54:	learn: 0.6454586	total: 7.53s	remaining: 6.16s
# 55:	learn: 0.6351312	total: 7.72s	remaining: 6.06s
# 56:	learn: 0.6313117	total: 7.83s	remaining: 5.91s
# 57:	learn: 0.6233423	total: 7.94s	remaining: 5.75s
# 58:	learn: 0.6196168	total: 8.05s	remaining: 5.6s
# 59:	learn: 0.6168914	total: 8.25s	remaining: 5.5s
# 60:	learn: 0.6131146	total: 8.45s	remaining: 5.4s
# 61:	learn: 0.6066858	total: 8.58s	remaining: 5.26s
# 62:	learn: 0.6042467	total: 8.67s	remaining: 5.09s
# 63:	learn: 0.5998944	total: 8.77s	remaining: 4.93s
# 64:	learn: 0.5972490	total: 8.88s	remaining: 4.78s
# 65:	learn: 0.5950486	total: 8.98s	remaining: 4.62s
# 66:	learn: 0.5919441	total: 9.07s	remaining: 4.47s
# 67:	learn: 0.5892879	total: 9.18s	remaining: 4.32s
# 68:	learn: 0.5866190	total: 9.27s	remaining: 4.17s
# 69:	learn: 0.5835523	total: 9.36s	remaining: 4.01s
# 70:	learn: 0.5804713	total: 9.47s	remaining: 3.87s
# 71:	learn: 0.5775556	total: 9.56s	remaining: 3.72s
# 72:	learn: 0.5744169	total: 9.65s	remaining: 3.57s
# 73:	learn: 0.5712968	total: 9.8s	remaining: 3.44s
# 74:	learn: 0.5685531	total: 9.96s	remaining: 3.32s
# 75:	learn: 0.5662464	total: 10.2s	remaining: 3.21s
# 76:	learn: 0.5638186	total: 10.3s	remaining: 3.08s
# 77:	learn: 0.5607087	total: 10.4s	remaining: 2.94s
# 78:	learn: 0.5572810	total: 10.5s	remaining: 2.8s
# 79:	learn: 0.5557080	total: 10.7s	remaining: 2.69s
# 80:	learn: 0.5526924	total: 10.9s	remaining: 2.56s
# 81:	learn: 0.5512818	total: 11s	remaining: 2.42s
# 82:	learn: 0.5428020	total: 11.2s	remaining: 2.29s
# 83:	learn: 0.5399366	total: 11.3s	remaining: 2.15s
# 84:	learn: 0.5340086	total: 11.4s	remaining: 2.01s
# 85:	learn: 0.5325964	total: 11.5s	remaining: 1.87s
# 86:	learn: 0.5302550	total: 11.6s	remaining: 1.73s
# 87:	learn: 0.5284719	total: 11.7s	remaining: 1.59s
# 88:	learn: 0.5255732	total: 11.8s	remaining: 1.46s
# 89:	learn: 0.5200947	total: 11.9s	remaining: 1.32s
# 90:	learn: 0.5175056	total: 12s	remaining: 1.19s
# 91:	learn: 0.5146291	total: 12.1s	remaining: 1.05s
# 92:	learn: 0.5115037	total: 12.2s	remaining: 920ms
# 93:	learn: 0.5081474	total: 12.3s	remaining: 787ms
# 94:	learn: 0.5066779	total: 12.4s	remaining: 653ms
# 95:	learn: 0.5046454	total: 12.5s	remaining: 522ms
# 96:	learn: 0.5018258	total: 12.6s	remaining: 390ms
# 97:	learn: 0.4990905	total: 12.7s	remaining: 259ms
# 98:	learn: 0.4958905	total: 12.8s	remaining: 130ms
# 99:	learn: 0.4924465	total: 12.9s	remaining: 0us
# 0:	learn: 4.6432447	total: 92.2ms	remaining: 9.13s
# 1:	learn: 3.4922031	total: 184ms	remaining: 9.03s
# 2:	learn: 2.7754949	total: 272ms	remaining: 8.81s
# 3:	learn: 2.5140788	total: 386ms	remaining: 9.26s
# 4:	learn: 2.3239518	total: 477ms	remaining: 9.07s
# 5:	learn: 2.0591284	total: 574ms	remaining: 8.99s
# 6:	learn: 1.7509605	total: 698ms	remaining: 9.27s
# 7:	learn: 1.7015303	total: 918ms	remaining: 10.6s
# 8:	learn: 1.6298965	total: 1.09s	remaining: 11s
# 9:	learn: 1.5851080	total: 1.21s	remaining: 10.9s
# 10:	learn: 1.4498583	total: 1.3s	remaining: 10.6s
# 11:	learn: 1.3557070	total: 1.39s	remaining: 10.2s
# 12:	learn: 1.2460714	total: 1.51s	remaining: 10.1s
# 13:	learn: 1.2125714	total: 1.6s	remaining: 9.82s
# 14:	learn: 1.1818485	total: 1.69s	remaining: 9.58s
# 15:	learn: 1.1300931	total: 1.81s	remaining: 9.53s
# 16:	learn: 1.0829539	total: 1.98s	remaining: 9.68s
# 17:	learn: 1.0677558	total: 2.17s	remaining: 9.88s
# 18:	learn: 1.0515813	total: 2.29s	remaining: 9.78s
# 19:	learn: 1.0144643	total: 2.39s	remaining: 9.58s
# 20:	learn: 0.9986752	total: 2.56s	remaining: 9.62s
# 21:	learn: 0.9710705	total: 2.72s	remaining: 9.63s
# 22:	learn: 0.9638162	total: 2.81s	remaining: 9.4s
# 23:	learn: 0.9578778	total: 2.9s	remaining: 9.19s
# 24:	learn: 0.9213269	total: 3.02s	remaining: 9.05s
# 25:	learn: 0.8803849	total: 3.11s	remaining: 8.86s
# 26:	learn: 0.8400963	total: 3.21s	remaining: 8.67s
# 27:	learn: 0.8026146	total: 3.37s	remaining: 8.66s
# 28:	learn: 0.7897612	total: 3.56s	remaining: 8.72s
# 29:	learn: 0.7846710	total: 3.72s	remaining: 8.69s
# 30:	learn: 0.7791851	total: 3.89s	remaining: 8.67s
# 31:	learn: 0.7763806	total: 4.03s	remaining: 8.56s
# 32:	learn: 0.7702312	total: 4.13s	remaining: 8.38s
# 33:	learn: 0.7630632	total: 4.22s	remaining: 8.19s
# 34:	learn: 0.7584571	total: 4.33s	remaining: 8.05s
# 35:	learn: 0.7501048	total: 4.43s	remaining: 7.87s
# 36:	learn: 0.7292702	total: 4.52s	remaining: 7.7s
# 37:	learn: 0.7267628	total: 4.63s	remaining: 7.56s
# 38:	learn: 0.7159124	total: 4.73s	remaining: 7.4s
# 39:	learn: 0.7115112	total: 4.86s	remaining: 7.28s
# 40:	learn: 0.7077408	total: 5.04s	remaining: 7.25s
# 41:	learn: 0.7045298	total: 5.17s	remaining: 7.15s
# 42:	learn: 0.6979605	total: 5.27s	remaining: 6.99s
# 43:	learn: 0.6892723	total: 5.38s	remaining: 6.84s
# 44:	learn: 0.6795367	total: 5.55s	remaining: 6.78s
# 45:	learn: 0.6746188	total: 5.72s	remaining: 6.71s
# 46:	learn: 0.6673222	total: 5.89s	remaining: 6.64s
# 47:	learn: 0.6642494	total: 6.02s	remaining: 6.52s
# 48:	learn: 0.6595956	total: 6.16s	remaining: 6.41s
# 49:	learn: 0.6560806	total: 6.27s	remaining: 6.27s
# 50:	learn: 0.6515276	total: 6.38s	remaining: 6.13s
# 51:	learn: 0.6452525	total: 6.53s	remaining: 6.02s
# 52:	learn: 0.6425381	total: 6.68s	remaining: 5.92s
# 53:	learn: 0.6392877	total: 6.8s	remaining: 5.79s
# 54:	learn: 0.6241791	total: 6.9s	remaining: 5.64s
# 55:	learn: 0.6179649	total: 7s	remaining: 5.5s
# 56:	learn: 0.6137980	total: 7.11s	remaining: 5.37s
# 57:	learn: 0.6105039	total: 7.2s	remaining: 5.22s
# 58:	learn: 0.6076463	total: 7.3s	remaining: 5.07s
# 59:	learn: 0.6044295	total: 7.41s	remaining: 4.94s
# 60:	learn: 0.6015514	total: 7.5s	remaining: 4.8s
# 61:	learn: 0.5986703	total: 7.59s	remaining: 4.65s
# 62:	learn: 0.5936983	total: 7.71s	remaining: 4.53s
# 63:	learn: 0.5898544	total: 7.8s	remaining: 4.39s
# 64:	learn: 0.5782107	total: 7.89s	remaining: 4.25s
# 65:	learn: 0.5744146	total: 8.01s	remaining: 4.13s
# 66:	learn: 0.5720760	total: 8.1s	remaining: 3.99s
# 67:	learn: 0.5695706	total: 8.19s	remaining: 3.85s
# 68:	learn: 0.5660824	total: 8.31s	remaining: 3.73s
# 69:	learn: 0.5634357	total: 8.4s	remaining: 3.6s
# 70:	learn: 0.5605073	total: 8.5s	remaining: 3.47s
# 71:	learn: 0.5563878	total: 8.62s	remaining: 3.35s
# 72:	learn: 0.5532438	total: 8.72s	remaining: 3.23s
# 73:	learn: 0.5500317	total: 8.82s	remaining: 3.1s
# 74:	learn: 0.5437739	total: 8.94s	remaining: 2.98s
# 75:	learn: 0.5409216	total: 9.04s	remaining: 2.85s
# 76:	learn: 0.5376452	total: 9.15s	remaining: 2.73s
# 77:	learn: 0.5356259	total: 9.26s	remaining: 2.61s
# 78:	learn: 0.5327022	total: 9.37s	remaining: 2.49s
# 79:	learn: 0.5297293	total: 9.46s	remaining: 2.37s
# 80:	learn: 0.5275120	total: 9.58s	remaining: 2.25s
# 81:	learn: 0.5256186	total: 9.67s	remaining: 2.12s
# 82:	learn: 0.5228735	total: 9.78s	remaining: 2s
# 83:	learn: 0.5184936	total: 9.89s	remaining: 1.88s
# 84:	learn: 0.5165509	total: 10s	remaining: 1.76s
# 85:	learn: 0.5146981	total: 10.1s	remaining: 1.64s
# 86:	learn: 0.5131548	total: 10.2s	remaining: 1.52s
# 87:	learn: 0.5096193	total: 10.3s	remaining: 1.4s
# 88:	learn: 0.5071870	total: 10.4s	remaining: 1.29s
# 89:	learn: 0.5047782	total: 10.5s	remaining: 1.17s
# 90:	learn: 0.5025992	total: 10.6s	remaining: 1.05s
# 91:	learn: 0.5002466	total: 10.7s	remaining: 933ms
# 92:	learn: 0.4959994	total: 10.8s	remaining: 816ms
# 93:	learn: 0.4921469	total: 10.9s	remaining: 699ms
# 94:	learn: 0.4889893	total: 11.1s	remaining: 582ms
# 95:	learn: 0.4874883	total: 11.1s	remaining: 465ms
# 96:	learn: 0.4858261	total: 11.3s	remaining: 348ms
# 97:	learn: 0.4836166	total: 11.4s	remaining: 232ms
# 98:	learn: 0.4807767	total: 11.5s	remaining: 116ms
# 99:	learn: 0.4788329	total: 11.7s	remaining: 0us
# 0:	learn: 4.6755969	total: 87.8ms	remaining: 8.7s
# 1:	learn: 3.3570778	total: 184ms	remaining: 9.03s
# 2:	learn: 2.8320330	total: 272ms	remaining: 8.81s
# 3:	learn: 2.6754499	total: 387ms	remaining: 9.28s
# 4:	learn: 2.4097687	total: 488ms	remaining: 9.27s
# 5:	learn: 2.1875282	total: 683ms	remaining: 10.7s
# 6:	learn: 2.1151652	total: 841ms	remaining: 11.2s
# 7:	learn: 2.0262106	total: 1s	remaining: 11.5s
# 8:	learn: 1.9769604	total: 1.19s	remaining: 12s
# 9:	learn: 1.9200722	total: 1.33s	remaining: 12s
# 10:	learn: 1.7648549	total: 1.45s	remaining: 11.7s
# 11:	learn: 1.7143804	total: 1.55s	remaining: 11.4s
# 12:	learn: 1.5651433	total: 1.73s	remaining: 11.6s
# 13:	learn: 1.5149262	total: 1.9s	remaining: 11.7s
# 14:	learn: 1.4253183	total: 2.04s	remaining: 11.5s
# 15:	learn: 1.3768351	total: 2.15s	remaining: 11.3s
# 16:	learn: 1.3273476	total: 2.31s	remaining: 11.3s
# 17:	learn: 1.2694660	total: 2.44s	remaining: 11.1s
# 18:	learn: 1.2528444	total: 2.53s	remaining: 10.8s
# 19:	learn: 1.2229937	total: 2.65s	remaining: 10.6s
# 20:	learn: 1.1765573	total: 2.81s	remaining: 10.6s
# 21:	learn: 1.1168967	total: 2.95s	remaining: 10.5s
# 22:	learn: 1.0657416	total: 3.08s	remaining: 10.3s
# 23:	learn: 1.0587312	total: 3.19s	remaining: 10.1s
# 24:	learn: 1.0449910	total: 3.29s	remaining: 9.87s
# 25:	learn: 1.0388383	total: 3.38s	remaining: 9.63s
# 26:	learn: 1.0310015	total: 3.5s	remaining: 9.46s
# 27:	learn: 1.0163914	total: 3.59s	remaining: 9.23s
# 28:	learn: 1.0080709	total: 3.68s	remaining: 9.01s
# 29:	learn: 1.0026067	total: 3.79s	remaining: 8.85s
# 30:	learn: 0.9761702	total: 3.9s	remaining: 8.68s
# 31:	learn: 0.9678018	total: 4.08s	remaining: 8.68s
# 32:	learn: 0.9555745	total: 4.27s	remaining: 8.67s
# 33:	learn: 0.9487810	total: 4.46s	remaining: 8.65s
# 34:	learn: 0.9440028	total: 4.65s	remaining: 8.63s
# 35:	learn: 0.9374276	total: 4.78s	remaining: 8.49s
# 36:	learn: 0.9158769	total: 4.87s	remaining: 8.3s
# 37:	learn: 0.9114152	total: 4.96s	remaining: 8.09s
# 38:	learn: 0.8985426	total: 5.08s	remaining: 7.95s
# 39:	learn: 0.8534976	total: 5.26s	remaining: 7.9s
# 40:	learn: 0.8488711	total: 5.39s	remaining: 7.76s
# 41:	learn: 0.8434023	total: 5.52s	remaining: 7.63s
# 42:	learn: 0.8406809	total: 5.63s	remaining: 7.46s
# 43:	learn: 0.8367816	total: 5.79s	remaining: 7.37s
# 44:	learn: 0.8331083	total: 5.94s	remaining: 7.26s
# 45:	learn: 0.8255878	total: 6.04s	remaining: 7.08s
# 46:	learn: 0.8129049	total: 6.13s	remaining: 6.91s
# 47:	learn: 0.7968655	total: 6.24s	remaining: 6.76s
# 48:	learn: 0.7908120	total: 6.33s	remaining: 6.59s
# 49:	learn: 0.7861678	total: 6.43s	remaining: 6.43s
# 50:	learn: 0.7789308	total: 6.54s	remaining: 6.28s
# 51:	learn: 0.7747297	total: 6.63s	remaining: 6.12s
# 52:	learn: 0.7712294	total: 6.72s	remaining: 5.96s
# 53:	learn: 0.7668728	total: 6.84s	remaining: 5.83s
# 54:	learn: 0.7635648	total: 6.93s	remaining: 5.67s
# 55:	learn: 0.7571816	total: 7.02s	remaining: 5.51s
# 56:	learn: 0.7534970	total: 7.13s	remaining: 5.38s
# 57:	learn: 0.7489729	total: 7.24s	remaining: 5.24s
# 58:	learn: 0.7382146	total: 7.43s	remaining: 5.17s
# 59:	learn: 0.7344243	total: 7.56s	remaining: 5.04s
# 60:	learn: 0.7316175	total: 7.66s	remaining: 4.9s
# 61:	learn: 0.7266853	total: 7.76s	remaining: 4.76s
# 62:	learn: 0.7226254	total: 7.86s	remaining: 4.62s
# 63:	learn: 0.7171162	total: 7.98s	remaining: 4.49s
# 64:	learn: 0.7136505	total: 8.14s	remaining: 4.38s
# 65:	learn: 0.6992415	total: 8.26s	remaining: 4.26s
# 66:	learn: 0.6956001	total: 8.41s	remaining: 4.14s
# 67:	learn: 0.6929220	total: 8.53s	remaining: 4.02s
# 68:	learn: 0.6892918	total: 8.63s	remaining: 3.88s
# 69:	learn: 0.6861380	total: 8.72s	remaining: 3.74s
# 70:	learn: 0.6819123	total: 8.84s	remaining: 3.61s
# 71:	learn: 0.6784722	total: 9.01s	remaining: 3.5s
# 72:	learn: 0.6747322	total: 9.16s	remaining: 3.39s
# 73:	learn: 0.6713178	total: 9.29s	remaining: 3.26s
# 74:	learn: 0.6676951	total: 9.39s	remaining: 3.13s
# 75:	learn: 0.6634602	total: 9.57s	remaining: 3.02s
# 76:	learn: 0.6589453	total: 9.69s	remaining: 2.9s
# 77:	learn: 0.6550375	total: 9.78s	remaining: 2.76s
# 78:	learn: 0.6512265	total: 9.88s	remaining: 2.63s
# 79:	learn: 0.6490130	total: 10.1s	remaining: 2.51s
# 80:	learn: 0.6448618	total: 10.2s	remaining: 2.39s
# 81:	learn: 0.6416932	total: 10.3s	remaining: 2.26s
# 82:	learn: 0.6393059	total: 10.5s	remaining: 2.14s
# 83:	learn: 0.6315739	total: 10.6s	remaining: 2.02s
# 84:	learn: 0.6287273	total: 10.8s	remaining: 1.9s
# 85:	learn: 0.6263198	total: 10.9s	remaining: 1.77s
# 86:	learn: 0.6234442	total: 11s	remaining: 1.64s
# 87:	learn: 0.6203320	total: 11.1s	remaining: 1.52s
# 88:	learn: 0.6138815	total: 11.3s	remaining: 1.4s
# 89:	learn: 0.6110686	total: 11.4s	remaining: 1.27s
# 90:	learn: 0.6084014	total: 11.6s	remaining: 1.15s
# 91:	learn: 0.6049797	total: 11.7s	remaining: 1.02s
# 92:	learn: 0.6016438	total: 11.8s	remaining: 888ms
# 93:	learn: 0.5975848	total: 11.9s	remaining: 760ms
# 94:	learn: 0.5963753	total: 12s	remaining: 634ms
# 95:	learn: 0.5938200	total: 12.2s	remaining: 507ms
# 96:	learn: 0.5907980	total: 12.3s	remaining: 380ms
# 97:	learn: 0.5877166	total: 12.4s	remaining: 253ms
# 98:	learn: 0.5853746	total: 12.5s	remaining: 126ms
# 99:	learn: 0.5830264	total: 12.6s	remaining: 0us
# 0:	learn: 4.6766005	total: 88.2ms	remaining: 8.73s
# 1:	learn: 3.3447585	total: 184ms	remaining: 9.02s
# 2:	learn: 2.8514272	total: 274ms	remaining: 8.84s
# 3:	learn: 2.4959667	total: 394ms	remaining: 9.45s
# 4:	learn: 2.3922050	total: 481ms	remaining: 9.15s
# 5:	learn: 2.1726675	total: 577ms	remaining: 9.04s
# 6:	learn: 2.0825474	total: 693ms	remaining: 9.21s
# 7:	learn: 1.8561996	total: 787ms	remaining: 9.05s
# 8:	learn: 1.7674756	total: 877ms	remaining: 8.87s
# 9:	learn: 1.7010961	total: 1.03s	remaining: 9.23s
# 10:	learn: 1.6183296	total: 1.2s	remaining: 9.73s
# 11:	learn: 1.5126479	total: 1.37s	remaining: 10.1s
# 12:	learn: 1.4524283	total: 1.49s	remaining: 10s
# 13:	learn: 1.3955046	total: 1.61s	remaining: 9.88s
# 14:	learn: 1.3850679	total: 1.76s	remaining: 9.98s
# 15:	learn: 1.3341970	total: 1.88s	remaining: 9.87s
# 16:	learn: 1.3228505	total: 1.97s	remaining: 9.62s
# 17:	learn: 1.3150768	total: 2.06s	remaining: 9.39s
# 18:	learn: 1.3091432	total: 2.18s	remaining: 9.28s
# 19:	learn: 1.2900567	total: 2.27s	remaining: 9.07s
# 20:	learn: 1.2800962	total: 2.4s	remaining: 9.02s
# 21:	learn: 1.2715217	total: 2.58s	remaining: 9.15s
# 22:	learn: 1.2534235	total: 2.73s	remaining: 9.12s
# 23:	learn: 1.2465772	total: 2.85s	remaining: 9.04s
# 24:	learn: 1.1475605	total: 3.01s	remaining: 9.04s
# 25:	learn: 1.1394247	total: 3.23s	remaining: 9.2s
# 26:	learn: 1.1324704	total: 3.46s	remaining: 9.37s
# 27:	learn: 1.1101710	total: 3.67s	remaining: 9.45s
# 28:	learn: 1.1047999	total: 3.89s	remaining: 9.53s
# 29:	learn: 1.0969801	total: 4.09s	remaining: 9.55s
# 30:	learn: 1.0835961	total: 4.34s	remaining: 9.65s
# 31:	learn: 1.0767974	total: 4.46s	remaining: 9.48s
# 32:	learn: 1.0690932	total: 4.57s	remaining: 9.27s
# 33:	learn: 1.0618664	total: 4.68s	remaining: 9.09s
# 34:	learn: 1.0540425	total: 4.79s	remaining: 8.9s
# 35:	learn: 1.0484925	total: 4.91s	remaining: 8.74s
# 36:	learn: 1.0422968	total: 5.03s	remaining: 8.56s
# 37:	learn: 1.0350480	total: 5.14s	remaining: 8.39s
# 38:	learn: 1.0165593	total: 5.31s	remaining: 8.3s
# 39:	learn: 0.9893021	total: 5.49s	remaining: 8.24s
# 40:	learn: 0.9828994	total: 5.61s	remaining: 8.07s
# 41:	learn: 0.9795462	total: 5.7s	remaining: 7.87s
# 42:	learn: 0.9765641	total: 5.82s	remaining: 7.72s
# 43:	learn: 0.9727047	total: 5.99s	remaining: 7.62s
# 44:	learn: 0.9667848	total: 6.2s	remaining: 7.57s
# 45:	learn: 0.9610133	total: 6.36s	remaining: 7.47s
# 46:	learn: 0.9477432	total: 6.58s	remaining: 7.42s
# 47:	learn: 0.9385914	total: 6.78s	remaining: 7.34s
# 48:	learn: 0.9267154	total: 6.98s	remaining: 7.26s
# 49:	learn: 0.9162473	total: 7.1s	remaining: 7.1s
# 50:	learn: 0.9048190	total: 7.2s	remaining: 6.92s
# 51:	learn: 0.9000384	total: 7.36s	remaining: 6.79s
# 52:	learn: 0.8952103	total: 7.48s	remaining: 6.63s
# 53:	learn: 0.8792459	total: 7.64s	remaining: 6.51s
# 54:	learn: 0.8733381	total: 7.77s	remaining: 6.36s
# 55:	learn: 0.8683166	total: 7.9s	remaining: 6.21s
# 56:	learn: 0.8640730	total: 8.01s	remaining: 6.04s
# 57:	learn: 0.8600556	total: 8.17s	remaining: 5.92s
# 58:	learn: 0.8539644	total: 8.31s	remaining: 5.78s
# 59:	learn: 0.8484891	total: 8.5s	remaining: 5.67s
# 60:	learn: 0.8430915	total: 8.64s	remaining: 5.52s
# 61:	learn: 0.8272394	total: 8.77s	remaining: 5.38s
# 62:	learn: 0.8189907	total: 8.93s	remaining: 5.25s
# 63:	learn: 0.8149707	total: 9.1s	remaining: 5.12s
# 64:	learn: 0.8041788	total: 9.22s	remaining: 4.97s
# 65:	learn: 0.7999974	total: 9.37s	remaining: 4.83s
# 66:	learn: 0.7974782	total: 9.47s	remaining: 4.66s
# 67:	learn: 0.7943006	total: 9.63s	remaining: 4.53s
# 68:	learn: 0.7896483	total: 9.79s	remaining: 4.4s
# 69:	learn: 0.7808922	total: 9.89s	remaining: 4.24s
# 70:	learn: 0.7783422	total: 9.99s	remaining: 4.08s
# 71:	learn: 0.7737487	total: 10.1s	remaining: 3.93s
# 72:	learn: 0.7706691	total: 10.2s	remaining: 3.77s
# 73:	learn: 0.7622603	total: 10.3s	remaining: 3.62s
# 74:	learn: 0.7523644	total: 10.4s	remaining: 3.48s
# 75:	learn: 0.7488039	total: 10.5s	remaining: 3.32s
# 76:	learn: 0.7438367	total: 10.6s	remaining: 3.17s
# 77:	learn: 0.7365749	total: 10.7s	remaining: 3.03s
# 78:	learn: 0.7319439	total: 10.8s	remaining: 2.88s
# 79:	learn: 0.7283356	total: 11.1s	remaining: 2.77s
# 80:	learn: 0.7240931	total: 11.2s	remaining: 2.63s
# 81:	learn: 0.7210843	total: 11.3s	remaining: 2.48s
# 82:	learn: 0.7182735	total: 11.4s	remaining: 2.34s
# 83:	learn: 0.7148290	total: 11.5s	remaining: 2.19s
# 84:	learn: 0.7101874	total: 11.6s	remaining: 2.05s
# 85:	learn: 0.7074782	total: 11.7s	remaining: 1.91s
# 86:	learn: 0.7035249	total: 11.8s	remaining: 1.77s
# 87:	learn: 0.6994089	total: 11.9s	remaining: 1.63s
# 88:	learn: 0.6955219	total: 12.1s	remaining: 1.5s
# 89:	learn: 0.6916125	total: 12.3s	remaining: 1.36s
# 90:	learn: 0.6892031	total: 12.4s	remaining: 1.23s
# 91:	learn: 0.6859396	total: 12.5s	remaining: 1.09s
# 92:	learn: 0.6793197	total: 12.6s	remaining: 950ms
# 93:	learn: 0.6757774	total: 12.7s	remaining: 812ms
# 94:	learn: 0.6723078	total: 12.8s	remaining: 676ms
# 95:	learn: 0.6689322	total: 12.9s	remaining: 539ms
# 96:	learn: 0.6667919	total: 13s	remaining: 403ms
# 97:	learn: 0.6638657	total: 13.1s	remaining: 268ms
# 98:	learn: 0.6616720	total: 13.3s	remaining: 135ms
# 99:	learn: 0.6589300	total: 13.5s	remaining: 0us
# 95% confindence interval:
# r2_score: 0.99138 (+/- 0.00493)
# MSE: 1.40912 (+/- 0.84711)
# MAE: 0.74518 (+/- 0.19302)

# %%
print_lr_score(X_polynomial, catboost_reg)

# %%
np.save("./data/X.npy", X)
np.save("./data/X_polynomial.npy", X_polynomial)
np.save("./data/y.npy", y)

# %%
X_saved = np.load('./data/X.npy')

# %% [markdown]
# ### Impuls graphs for different signal frequencies

# %%
    plt.rcParams["figure.figsize"] = [6, 4]

# %%
for freq in range(10, 600, 10):
    x = X[0, ::freq]

    plt.title("Frequency: " + str(freq))
    plt.ylim(np.min(X), np.max(X))
    plt.plot(range(1, len(X[0]), freq), x)
    plt.show()
